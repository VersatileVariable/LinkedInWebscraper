# %% [markdown]
# #Docs:
# #https://github.com/networkx/networkx/blob/main/doc/reference/functions.rst
# #Example with facebook - https://networkx.org/nx-guides/content/exploratory_notebooks/facebook_notebook.html

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from random import randint
import networkx as nx
import matplotlib.pyplot as plt

A = nx.Graph()

# %%
#add nodes
i = 1
while i < 26:
    A.add_node(i)
    i += 1


#add edges
G.add_edges_from([(1, 2), (1, 3), (1, 3), (1, 3), (1, 3), (1, 3)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/h9/gjl0cmmn7wggh47qkzzfvbh80000gn/T/ipykernel_3198/3433525791.py in <module>
#       7
#       8 #add edges
# ----> 9 G.add_edges_from([(1, 2), (1, 3), (1, 3), (1, 3), (1, 3), (1, 3)])
#
# NameError: name 'G' is not defined

# %%
#check
A.number_of_nodes()

#list them out
#list(A.nodes)

#list(A.edges)
# Out:
# 25

# %%
A.number_of_edges()

# %%
plt.show()  

options = {
    'node_color': 'purple',
    'node_size': 100,
    'width': 3,
}
subax1 = plt.subplot(221)
nx.draw_random(A, **options)
subax2 = plt.subplot(222)
nx.draw_circular(A, **options)
subax3 = plt.subplot(223)
nx.draw_spectral(A, **options)
subax4 = plt.subplot(224)
nx.draw_shell(A, nlist=[range(1,26), range(14)], **options)

# %%
#weighted nodes
G = nx.petersen_graph()

subax1 = plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
subax2 = plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')

# %%
DG = nx.DiGraph()
DG.add_edge(2, 1)   # adds the nodes in order 2, 1
DG.add_edge(1, 3)
DG.add_edge(2, 4)
DG.add_edge(1, 2)
assert list(DG.successors(2)) == [1, 4]
assert list(DG.edges) == [(2, 1), (2, 4), (1, 3), (1, 2)]

# %%
G = nx.dodecahedral_graph()
shells = [[2, 3, 4, 5, 6], [8, 1, 0, 19, 18, 17, 16, 15, 14, 7], [9, 10, 11, 12, 13]]
nx.draw_shell(G, nlist=shells, **options)

# %%
#saving drawings
nx.draw(G)
plt.savefig("path.png")

# %%
linkedin = pd.read_csv(
    "data/linkedin_combined.txt.gz",
    compression="gzip",
    sep=" ",
    names=["start_node", "end_node"],
)
G = nx.from_pandas_edgelist(facebook, "start_node", "end_node")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/h9/gjl0cmmn7wggh47qkzzfvbh80000gn/T/ipykernel_1121/2328846489.py in <module>
# ----> 1 linkedin = pd.read_csv(
#       2     "data/linkedin_combined.txt.gz",
#       3     compression="gzip",
#       4     sep=" ",
#       5     names=["start_node", "end_node"],
#
# /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 9))
ax.axis("off")
plot_options = {"node_size": 10, "with_labels": False, "width": 0.15}
nx.draw_networkx(G, pos=nx.random_layout(G), ax=ax, **plot_options)

# %%
pos = nx.spring_layout(G, iterations=15, seed=1721)
fig, ax = plt.subplots(figsize=(15, 9))
ax.axis("off")
nx.draw_networkx(G, pos=pos, ax=ax, **plot_options)
